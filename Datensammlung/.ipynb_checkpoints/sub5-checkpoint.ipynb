# %%
import requests
from bs4 import BeautifulSoup
import csv
import re

# %%
base_url = 'https://www.exchangeandmart.co.uk/ad/'
start_ad_id = 30818972
end_ad_id = 30860000

# %%
with open('car_listings_1.csv', 'a', newline='', encoding='utf-8') as csv_file:
    fieldnames = ['Make', 'Model', 'Price', 'Year', 'Engine Size','Mileage', 'Fuel Type', 'Transmission', 'Color', 'Body Type', 'Wheel Drive', 'Doors', 'Seats', 'Engine Power', 'Top Speed', 'Acceleration', 'CO2 Rating']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    if csv_file.tell() == 0:
        writer.writeheader()

    for ad_id in range(start_ad_id, end_ad_id + 1):
        url = f'{base_url}{ad_id}'
        response = requests.get(url)

        try:
            response.raise_for_status()

            html = response.text
            soup = BeautifulSoup(html, 'html.parser')

            car_listing = soup.find('div', class_='car-name clearfix')

            # Initialize variables with None
            make = model = engine_size = price = year = fuel_type = mileage = transmission = color = body_type = mpg = engine_power = top_speed = acceleration = co2_rating = seats = doors = wheel_drive = None

            if car_listing:
                # Extract make and model
                make_model = car_listing.find('span', class_='ttl')
                if make_model:
                    make, model = make_model.get_text(strip=True).split(maxsplit=1)

                # Extract price
                price_span = car_listing.find('span', itemprop='price')
                price = price_span.get_text(strip=True) if price_span else None

                # Extract details from adDetails
                ad_details = soup.find('div', id='adDetails')
                if ad_details:
                    def get_text_safe(element):
                        return element.text if element else None
                                
                    year = get_text_safe(ad_details.find('div', class_='adDetsItem').find('span'))
                    engine_size = get_text_safe(ad_details.find_all('div', class_='adDetsItem')[1].find('span'))
                    mileage = get_text_safe(ad_details.find_all('div', class_='adDetsItem')[2].find('span'))
                    fuel_type = get_text_safe(ad_details.find_all('div', class_='adDetsItem')[3].find('span'))
                    transmission = get_text_safe(ad_details.find_all('div', class_='adDetsItem')[4].find('span'))
                    color = get_text_safe(ad_details.find_all('div', class_='adDetsItem')[5].find('span'))
                    body_type = get_text_safe(ad_details.find_all('div', class_='adDetsItem')[6].find('span'))
                    
                
                    # Extract details from adSpec
                    ad_spec = soup.find('div', {'id': 'adSpec', 'expand': 'adSpec'})
                    if ad_spec:
                        wheel_drive_elem = ad_spec.find('span', string='Wheel drive:')
                        wheel_drive = wheel_drive_elem.find_next('span').get_text(strip=True) if wheel_drive_elem and wheel_drive_elem.find_next('span') else None

                        doors_elem = ad_spec.find('span', string='Doors:')
                        doors = doors_elem.find_next('span').get_text(strip=True) if doors_elem and doors_elem.find_next('span') else None

                        seats_elem = ad_spec.find('span', string='Seats:')
                        seats = seats_elem.find_next('span').get_text(strip=True) if seats_elem and seats_elem.find_next('span') else None

                        engine_power_elem = ad_spec.find('span', string='Engine power:')
                        engine_power = engine_power_elem.find_next('span').get_text(strip=True) if engine_power_elem and engine_power_elem.find_next('span') else None

                        top_speed_elem = ad_spec.find('span', string='Top speed:')
                        top_speed = top_speed_elem.find_next('span').get_text(strip=True) if top_speed_elem and top_speed_elem.find_next('span') else None

                        acceleration_elem = ad_spec.find('span', string='Acceleration (0-62 mph):')
                        acceleration = acceleration_elem.find_next('span').get_text(strip=True) if acceleration_elem and acceleration_elem.find_next('span') else None

                        co2_rating_elem = ad_spec.find('span', string='CO2 rating:')
                        co2_rating = co2_rating_elem.find_next('span').get_text(strip=True) if co2_rating_elem and co2_rating_elem.find_next('span') else None
                        
                        
                        # Write to CSV
                        writer.writerow({
                            'Make': make,
                            'Model': model,
                            'Price': price,
                            'Year': year,
                            'Engine Size': engine_size,
                            'Mileage': mileage,
                            'Fuel Type': fuel_type,
                            'Transmission': transmission,
                            'Color': color,
                            'Body Type': body_type,
                            'Wheel Drive': wheel_drive,
                            'Doors': doors,
                            'Seats': seats,
                            'Engine Power': engine_power,
                            'Top Speed': top_speed,
                            'Acceleration': acceleration,
                            'CO2 Rating': co2_rating,
                        })

                        print(f"Data for ad ID {ad_id} has been written to CSV.")

                    else:
                        writer.writerow({
                            'Make': make,
                            'Model': model,
                            'Price': price,
                            'Year': year,
                            'Engine Size': engine_size,
                            'Mileage': mileage,
                            'Fuel Type': fuel_type,
                            'Transmission': transmission,
                            'Color': color,
                            'Body Type': body_type,
                            'Wheel Drive': wheel_drive,
                            'Doors': doors,
                            'Seats': seats,
                            'Engine Power': engine_power,
                            'Top Speed': top_speed,
                            'Acceleration': acceleration,
                            'CO2 Rating': co2_rating,
                        })
                        wheel_drive = doors = seats = engine_power = top_speed = acceleration = co2_rating = None
        except requests.HTTPError as e:
            if e.response.status_code == 404:
                print(f"Error 404: Page not found for ad ID {ad_id}")
            else:
                print(f"Error {e.response.status_code} for ad ID {ad_id}")

        except Exception as e:
            print(f"An unexpected error occurred for ad ID {ad_id}: {e}")
# Out:
# Error 404: Page not found for ad ID 30811832
# Data for ad ID 30811833 has been written to CSV.
# Data for ad ID 30811834 has been written to CSV.
# Data for ad ID 30811835 has been written to CSV.
# Data for ad ID 30811836 has been written to CSV.
# Data for ad ID 30811837 has been written to CSV.
# Data for ad ID 30811838 has been written to CSV.
# Data for ad ID 30811839 has been written to CSV.
# Data for ad ID 30811840 has been written to CSV.
# Error 404: Page not found for ad ID 30811841
# Error 404: Page not found for ad ID 30811842
# Error 404: Page not found for ad ID 30811843
# Error 404: Page not found for ad ID 30811844
# Error 404: Page not found for ad ID 30811845
# Data for ad ID 30811846 has been written to CSV.
# Error 404: Page not found for ad ID 30811847
# Error 404: Page not found for ad ID 30811848
# Data for ad ID 30811849 has been written to CSV.
# Data for ad ID 30811850 has been written to CSV.
# Error 404: Page not found for ad ID 30811851
# Error 404: Page not found for ad ID 30811852
# An unexpected error occurred for ad ID 30811853: list index out of range
# Data for ad ID 30811854 has been written to CSV.
# An unexpected error occurred for ad ID 30811855: list index out of range
# Data for ad ID 30811856 has been written to CSV.
# Data for ad ID 30811857 has been written to CSV.
# Error 404: Page not found for ad ID 30811858
# Error 404: Page not found for ad ID 30811859
# Data for ad ID 30811860 has been written to CSV.
# Data for ad ID 30811861 has been written to CSV.
# Data for ad ID 30811862 has been written to CSV.
# Error 404: Page not found for ad ID 30811863
# Data for ad ID 30811864 has been written to CSV.
# Data for ad ID 30811865 has been written to CSV.
# Data for ad ID 30812524 has been written to CSV.
# Error 404: Page not found for ad ID 30812525
# Error 404: Page not found for ad ID 30812526
# Error 404: Page not found for ad ID 30812527
# Error 404: Page not found for ad ID 30812528
# Error 404: Page not found for ad ID 30812529
# Data for ad ID 30812530 has been written to CSV.
# Data for ad ID 30812531 has been written to CSV.
# Data for ad ID 30812532 has been written to CSV.
# Data for ad ID 30812533 has been written to CSV.
# Data for ad ID 30812534 has been written to CSV.
# Error 404: Page not found for ad ID 30812535
# Data for ad ID 30812536 has been written to CSV.
# Data for ad ID 30812537 has been written to CSV.
# Data for ad ID 30812538 has been written to CSV.
# Data for ad ID 30812539 has been written to CSV.
# Data for ad ID 30812540 has been written to CSV.
# Data for ad ID 30812541 has been written to CSV.
# Data for ad ID 30812542 has been written to CSV.
# Data for ad ID 30812543 has been written to CSV.
# Data for ad ID 30812544 has been written to CSV.
# Data for ad ID 30812545 has been written to CSV.
# Error 404: Page not found for ad ID 30812546
# Data for ad ID 30812547 has been written to CSV.
# Data for ad ID 30812548 has been written to CSV.
# Error 404: Page not found for ad ID 30812549
# Data for ad ID 30812550 has been written to CSV.
# Data for ad ID 30812551 has been written to CSV.
# Data for ad ID 30812552 has been written to CSV.
# Data for ad ID 30812553 has been written to CSV.
# Error 404: Page not found for ad ID 30812554
# Data for ad ID 30812555 has been written to CSV.
# Data for ad ID 30812556 has been written to CSV.
# Data for ad ID 30812557 has been written to CSV.
# Data for ad ID 30812558 has been written to CSV.
# Data for ad ID 30812559 has been written to CSV.
# Data for ad ID 30812560 has been written to CSV.
# Data for ad ID 30812561 has been written to CSV.
# Data for ad ID 30812562 has been written to CSV.
# Data for ad ID 30812563 has been written to CSV.
# Error 404: Page not found for ad ID 30812564
# Error 404: Page not found for ad ID 30812565
# Error 404: Page not found for ad ID 30812566
# Data for ad ID 30812567 has been written to CSV.
# Error 404: Page not found for ad ID 30812568
# Error 404: Page not found for ad ID 30812569
# Error 404: Page not found for ad ID 30812570
# Data for ad ID 30812571 has been written to CSV.
# Data for ad ID 30812572 has been written to CSV.
# Data for ad ID 30812573 has been written to CSV.
# Data for ad ID 30812574 has been written to CSV.
# Data for ad ID 30812575 has been written to CSV.
# Data for ad ID 30812576 has been written to CSV.
# Data for ad ID 30812577 has been written to CSV.
# Data for ad ID 30812578 has been written to CSV.
# Data for ad ID 30812579 has been written to CSV.
# Data for ad ID 30812580 has been written to CSV.
# Data for ad ID 30812581 has been written to CSV.
# Data for ad ID 30812582 has been written to CSV.
# Error 404: Page not found for ad ID 30812583
# Error 404: Page not found for ad ID 30812584
# Data for ad ID 30812585 has been written to CSV.
# Data for ad ID 30812586 has been written to CSV.
# Error 404: Page not found for ad ID 30812587
# Data for ad ID 30812588 has been written to CSV.
# Data for ad ID 30812589 has been written to CSV.
# Error 404: Page not found for ad ID 30812590
# Data for ad ID 30812591 has been written to CSV.
# Error 404: Page not found for ad ID 30812592
# Data for ad ID 30812593 has been written to CSV.
# Data for ad ID 30812594 has been written to CSV.
# Data for ad ID 30812595 has been written to CSV.
# Data for ad ID 30812596 has been written to CSV.
# Data for ad ID 30812597 has been written to CSV.
# Data for ad ID 30812598 has been written to CSV.
# Data for ad ID 30812599 has been written to CSV.
# Error 404: Page not found for ad ID 30812600
# Error 404: Page not found for ad ID 30812601
# Data for ad ID 30812602 has been written to CSV.
# Data for ad ID 30812603 has been written to CSV.
# Error 404: Page not found for ad ID 30812604
# Data for ad ID 30812605 has been written to CSV.
# Data for ad ID 30812606 has been written to CSV.
# Data for ad ID 30812607 has been written to CSV.
# Error 404: Page not found for ad ID 30812608
# Data for ad ID 30812609 has been written to CSV.
# Error 404: Page not found for ad ID 30812610
# Data for ad ID 30812611 has been written to CSV.
# Data for ad ID 30812612 has been written to CSV.
# Data for ad ID 30812613 has been written to CSV.
# Error 404: Page not found for ad ID 30812614
# Data for ad ID 30812615 has been written to CSV.
# Error 404: Page not found for ad ID 30812616
# Data for ad ID 30812617 has been written to CSV.
# Data for ad ID 30812618 has been written to CSV.
# Error 404: Page not found for ad ID 30812619
# Data for ad ID 30812620 has been written to CSV.
# Data for ad ID 30812621 has been written to CSV.
# Data for ad ID 30812622 has been written to CSV.
# Data for ad ID 30812623 has been written to CSV.
# Data for ad ID 30812624 has been written to CSV.
# Error 404: Page not found for ad ID 30812625
# Data for ad ID 30812626 has been written to CSV.
# Data for ad ID 30812627 has been written to CSV.
# Data for ad ID 30812628 has been written to CSV.
# Data for ad ID 30812629 has been written to CSV.
# Data for ad ID 30812630 has been written to CSV.
# Error 404: Page not found for ad ID 30812632
# Data for ad ID 30812633 has been written to CSV.
# Data for ad ID 30812634 has been written to CSV.
# Data for ad ID 30812635 has been written to CSV.
# Data for ad ID 30812636 has been written to CSV.
# Error 404: Page not found for ad ID 30812637
# Data for ad ID 30812638 has been written to CSV.
# Data for ad ID 30812639 has been written to CSV.
# Error 404: Page not found for ad ID 30812640
# Error 404: Page not found for ad ID 30812641
# Error 404: Page not found for ad ID 30812642
# Data for ad ID 30812643 has been written to CSV.
# Error 404: Page not found for ad ID 30812644
# Error 404: Page not found for ad ID 30812645
# Error 404: Page not found for ad ID 30812646
# Data for ad ID 30812647 has been written to CSV.
# Data for ad ID 30812648 has been written to CSV.
# Data for ad ID 30812649 has been written to CSV.
# Data for ad ID 30812650 has been written to CSV.
# Data for ad ID 30812651 has been written to CSV.
# Data for ad ID 30812652 has been written to CSV.
# Data for ad ID 30812653 has been written to CSV.
# Error 404: Page not found for ad ID 30812654
# Data for ad ID 30812655 has been written to CSV.
# Error 404: Page not found for ad ID 30812656
# Error 404: Page not found for ad ID 30812657
# Data for ad ID 30812658 has been written to CSV.
# Error 404: Page not found for ad ID 30812659
# Error 404: Page not found for ad ID 30812660
# Data for ad ID 30812661 has been written to CSV.
# Data for ad ID 30812662 has been written to CSV.
# Data for ad ID 30812663 has been written to CSV.
# Error 404: Page not found for ad ID 30812664
# Error 404: Page not found for ad ID 30812665
# Data for ad ID 30812666 has been written to CSV.
# Data for ad ID 30812667 has been written to CSV.
# Data for ad ID 30812668 has been written to CSV.
# Data for ad ID 30812669 has been written to CSV.
# Data for ad ID 30812670 has been written to CSV.
# Data for ad ID 30812671 has been written to CSV.
# Data for ad ID 30812672 has been written to CSV.
# Data for ad ID 30812673 has been written to CSV.
# Data for ad ID 30812674 has been written to CSV.
# Error 404: Page not found for ad ID 30812675
# Error 404: Page not found for ad ID 30812677
# Data for ad ID 30812678 has been written to CSV.
# Error 404: Page not found for ad ID 30812679
# Data for ad ID 30812680 has been written to CSV.
# Data for ad ID 30812681 has been written to CSV.
# Error 404: Page not found for ad ID 30812682
# Data for ad ID 30812683 has been written to CSV.
# Error 404: Page not found for ad ID 30812684
# Data for ad ID 30812685 has been written to CSV.
# Error 404: Page not found for ad ID 30812686
# Error 404: Page not found for ad ID 30812687
# Data for ad ID 30812688 has been written to CSV.
# Data for ad ID 30812689 has been written to CSV.
# Data for ad ID 30812690 has been written to CSV.
# Data for ad ID 30812691 has been written to CSV.
# Data for ad ID 30812692 has been written to CSV.
# Data for ad ID 30812693 has been written to CSV.
# Data for ad ID 30812694 has been written to CSV.
# Data for ad ID 30812695 has been written to CSV.
# Error 404: Page not found for ad ID 30812696
# Error 404: Page not found for ad ID 30812697
# Data for ad ID 30812698 has been written to CSV.
# Data for ad ID 30812699 has been written to CSV.
# Error 404: Page not found for ad ID 30812700
# Data for ad ID 30812701 has been written to CSV.
# Data for ad ID 30812702 has been written to CSV.
# Data for ad ID 30812703 has been written to CSV.
# Data for ad ID 30812704 has been written to CSV.
# Data for ad ID 30812706 has been written to CSV.
# Data for ad ID 30812707 has been written to CSV.
# Data for ad ID 30812708 has been written to CSV.
# Data for ad ID 30812709 has been written to CSV.
# Data for ad ID 30812710 has been written to CSV.
# Data for ad ID 30812711 has been written to CSV.
# Data for ad ID 30812712 has been written to CSV.
# Data for ad ID 30812713 has been written to CSV.
# Data for ad ID 30812714 has been written to CSV.
# Data for ad ID 30812715 has been written to CSV.
# Error 404: Page not found for ad ID 30812716
# Error 404: Page not found for ad ID 30812717
# Data for ad ID 30812718 has been written to CSV.
# Data for ad ID 30812719 has been written to CSV.
# Data for ad ID 30812720 has been written to CSV.
# Data for ad ID 30812721 has been written to CSV.
# Data for ad ID 30812722 has been written to CSV.
# Data for ad ID 30812723 has been written to CSV.
# Data for ad ID 30812724 has been written to CSV.
# Data for ad ID 30812725 has been written to CSV.
# Data for ad ID 30812726 has been written to CSV.
# An unexpected error occurred for ad ID 30812727: list index out of range
# Data for ad ID 30812728 has been written to CSV.
# Data for ad ID 30812729 has been written to CSV.
# Data for ad ID 30812730 has been written to CSV.
# Data for ad ID 30812731 has been written to CSV.
# Error 404: Page not found for ad ID 30812733
# Data for ad ID 30812734 has been written to CSV.
# Data for ad ID 30812735 has been written to CSV.
# Data for ad ID 30812736 has been written to CSV.
# Data for ad ID 30812737 has been written to CSV.
# Data for ad ID 30812738 has been written to CSV.
# Error 404: Page not found for ad ID 30812739
# Error 404: Page not found for ad ID 30812740
# Error 404: Page not found for ad ID 30812741
# Error 404: Page not found for ad ID 30812742
# Data for ad ID 30812817 has been written to CSV.
# Data for ad ID 30812818 has been written to CSV.
# Error 404: Page not found for ad ID 30812819
# Data for ad ID 30812820 has been written to CSV.
# Error 404: Page not found for ad ID 30812821
# Data for ad ID 30812822 has been written to CSV.
# Error 404: Page not found for ad ID 30812823
# Data for ad ID 30812824 has been written to CSV.
# Data for ad ID 30812825 has been written to CSV.
# Data for ad ID 30812826 has been written to CSV.
# Data for ad ID 30812827 has been written to CSV.
# Error 404: Page not found for ad ID 30812828
# Data for ad ID 30812829 has been written to CSV.
# Data for ad ID 30812830 has been written to CSV.
# Data for ad ID 30812831 has been written to CSV.
# Error 404: Page not found for ad ID 30812832
# Error 404: Page not found for ad ID 30812834
# Data for ad ID 30812835 has been written to CSV.
# Error 404: Page not found for ad ID 30812836
# Data for ad ID 30812837 has been written to CSV.
# Data for ad ID 30812838 has been written to CSV.
# Data for ad ID 30812839 has been written to CSV.
# Data for ad ID 30812840 has been written to CSV.
# Error 404: Page not found for ad ID 30812841
# Data for ad ID 30812842 has been written to CSV.
# Data for ad ID 30812843 has been written to CSV.
# Data for ad ID 30812844 has been written to CSV.
# Error 404: Page not found for ad ID 30812845
# Data for ad ID 30812846 has been written to CSV.
# Data for ad ID 30812847 has been written to CSV.
# Error 404: Page not found for ad ID 30812848
# ...
# Error 404: Page not found for ad ID 30818683
# Error 404: Page not found for ad ID 30818684
# Data for ad ID 30818685 has been written to CSV.
# Error 404: Page not found for ad ID 30818686
# Data for ad ID 30818687 has been written to CSV.
# Data for ad ID 30818688 has been written to CSV.
# Data for ad ID 30818689 has been written to CSV.
# Data for ad ID 30818690 has been written to CSV.
# Error 404: Page not found for ad ID 30818691
# Data for ad ID 30818692 has been written to CSV.
# An unexpected error occurred for ad ID 30818693: list index out of range
# Error 404: Page not found for ad ID 30818694
# Error 404: Page not found for ad ID 30818695
# Error 404: Page not found for ad ID 30818696
# Error 404: Page not found for ad ID 30818697
# Data for ad ID 30818698 has been written to CSV.
# Data for ad ID 30818699 has been written to CSV.
# Data for ad ID 30818700 has been written to CSV.
# Data for ad ID 30818701 has been written to CSV.
# Data for ad ID 30818702 has been written to CSV.
# Error 404: Page not found for ad ID 30818703
# Error 404: Page not found for ad ID 30818704
# Data for ad ID 30818705 has been written to CSV.
# Data for ad ID 30818706 has been written to CSV.
# Data for ad ID 30818707 has been written to CSV.
# Data for ad ID 30818708 has been written to CSV.
# Data for ad ID 30818709 has been written to CSV.
# Error 404: Page not found for ad ID 30818710
# Error 404: Page not found for ad ID 30818711
# Error 404: Page not found for ad ID 30818712
# Error 404: Page not found for ad ID 30818713
# Error 404: Page not found for ad ID 30818714
# Data for ad ID 30818715 has been written to CSV.
# Data for ad ID 30818716 has been written to CSV.
# Data for ad ID 30818717 has been written to CSV.
# Data for ad ID 30818718 has been written to CSV.
# Error 404: Page not found for ad ID 30818719
# Data for ad ID 30818720 has been written to CSV.
# Data for ad ID 30818721 has been written to CSV.
# Data for ad ID 30818722 has been written to CSV.
# Data for ad ID 30818723 has been written to CSV.
# Error 404: Page not found for ad ID 30818724
# Data for ad ID 30818725 has been written to CSV.
# Data for ad ID 30818726 has been written to CSV.
# Data for ad ID 30818727 has been written to CSV.
# Data for ad ID 30818728 has been written to CSV.
# Data for ad ID 30818729 has been written to CSV.
# Data for ad ID 30818730 has been written to CSV.
# Data for ad ID 30818731 has been written to CSV.
# Data for ad ID 30818732 has been written to CSV.
# Error 404: Page not found for ad ID 30818733
# Data for ad ID 30818734 has been written to CSV.
# Data for ad ID 30818735 has been written to CSV.
# Error 404: Page not found for ad ID 30818736
# Error 404: Page not found for ad ID 30818737
# Data for ad ID 30818738 has been written to CSV.
# Data for ad ID 30818739 has been written to CSV.
# Error 404: Page not found for ad ID 30818740
# Data for ad ID 30818741 has been written to CSV.
# Data for ad ID 30818742 has been written to CSV.
# Error 404: Page not found for ad ID 30818743
# Error 404: Page not found for ad ID 30818744
# Data for ad ID 30818745 has been written to CSV.
# Data for ad ID 30818746 has been written to CSV.
# Data for ad ID 30818747 has been written to CSV.
# Error 404: Page not found for ad ID 30818748
# Data for ad ID 30818749 has been written to CSV.
# Error 404: Page not found for ad ID 30818750
# Data for ad ID 30818751 has been written to CSV.
# Error 404: Page not found for ad ID 30818752
# Data for ad ID 30818753 has been written to CSV.
# Error 404: Page not found for ad ID 30818754
# Error 404: Page not found for ad ID 30818755
# Error 404: Page not found for ad ID 30818756
# Error 404: Page not found for ad ID 30818757
# Data for ad ID 30818758 has been written to CSV.
# Error 404: Page not found for ad ID 30818759
# Data for ad ID 30818760 has been written to CSV.
# Error 404: Page not found for ad ID 30818761
# Data for ad ID 30818762 has been written to CSV.
# Data for ad ID 30818763 has been written to CSV.
# Data for ad ID 30818764 has been written to CSV.
# Data for ad ID 30818765 has been written to CSV.
# Data for ad ID 30818766 has been written to CSV.
# Error 404: Page not found for ad ID 30818767
# Error 404: Page not found for ad ID 30818768
# Error 404: Page not found for ad ID 30818769
# Data for ad ID 30818770 has been written to CSV.
# Data for ad ID 30818771 has been written to CSV.
# Data for ad ID 30818772 has been written to CSV.
# Data for ad ID 30818773 has been written to CSV.
# Error 404: Page not found for ad ID 30818774
# Error 404: Page not found for ad ID 30818775
# Error 404: Page not found for ad ID 30818776
# Data for ad ID 30818777 has been written to CSV.
# Data for ad ID 30818778 has been written to CSV.
# Data for ad ID 30818779 has been written to CSV.
# Data for ad ID 30818780 has been written to CSV.
# Data for ad ID 30818781 has been written to CSV.
# Error 404: Page not found for ad ID 30818782
# Data for ad ID 30818783 has been written to CSV.
# Error 404: Page not found for ad ID 30818784
# Data for ad ID 30818785 has been written to CSV.
# Data for ad ID 30818786 has been written to CSV.
# Error 404: Page not found for ad ID 30818787
# Error 404: Page not found for ad ID 30818788
# Data for ad ID 30818789 has been written to CSV.
# Data for ad ID 30818790 has been written to CSV.
# Error 404: Page not found for ad ID 30818791
# Data for ad ID 30818792 has been written to CSV.
# Data for ad ID 30818793 has been written to CSV.
# Data for ad ID 30818794 has been written to CSV.
# Data for ad ID 30818795 has been written to CSV.
# Data for ad ID 30818796 has been written to CSV.
# Data for ad ID 30818944 has been written to CSV.
# Error 404: Page not found for ad ID 30818945
# Error 404: Page not found for ad ID 30818946
# Data for ad ID 30818947 has been written to CSV.
# Data for ad ID 30818948 has been written to CSV.
# Data for ad ID 30818949 has been written to CSV.
# Data for ad ID 30818951 has been written to CSV.
# Data for ad ID 30818952 has been written to CSV.
# Data for ad ID 30818953 has been written to CSV.
# Error 404: Page not found for ad ID 30818954
# Data for ad ID 30818955 has been written to CSV.
# Data for ad ID 30818956 has been written to CSV.
# Error 404: Page not found for ad ID 30818957
# Data for ad ID 30818958 has been written to CSV.
# Data for ad ID 30818959 has been written to CSV.
# Data for ad ID 30818960 has been written to CSV.
# Data for ad ID 30818961 has been written to CSV.
# Data for ad ID 30818962 has been written to CSV.
# Data for ad ID 30818963 has been written to CSV.
# Data for ad ID 30818964 has been written to CSV.
# Error 404: Page not found for ad ID 30818965
# Data for ad ID 30818966 has been written to CSV.
# Data for ad ID 30818967 has been written to CSV.
# An unexpected error occurred for ad ID 30818968: list index out of range
# An unexpected error occurred for ad ID 30818969: list index out of range
# Data for ad ID 30818970 has been written to CSV.
# Data for ad ID 30818971 has been written to CSV.
# Data for ad ID 30818972 has been written to CSV.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 15
#      12 response.raise_for_status()
#      14 html = response.text
# ---> 15 soup = BeautifulSoup(html, 'html.parser')
#      17 car_listing = soup.find('div', class_='car-name clearfix')
#      19 # Initialize variables with None
#
# File ~\anaconda3\Lib\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File ~\anaconda3\Lib\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File ~\anaconda3\Lib\site-packages\bs4\builder\_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381 except AssertionError as e:
#     382     # html.parser raises AssertionError in rare cases to
#     383     # indicate a fatal problem with the markup, especially
#     384     # when there's an error in the doctype declaration.
#     385     raise ParserRejectedMarkup(e)
#
# File ~\anaconda3\Lib\html\parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~\anaconda3\Lib\html\parser.py:172, in HTMLParser.goahead(self, end)
#     170     k = self.parse_starttag(i)
#     171 elif startswith("</", i):
# --> 172     k = self.parse_endtag(i)
#     173 elif startswith("<!--", i):
#     174     k = self.parse_comment(i)
#
# File ~\anaconda3\Lib\html\parser.py:384, in HTMLParser.parse_endtag(self, i)
#     382 if not match:
#     383     return -1
# --> 384 gtpos = match.end()
#     385 match = endtagfind.match(rawdata, i) # </ + tag + >
#     386 if not match:
#
# KeyboardInterrupt:
